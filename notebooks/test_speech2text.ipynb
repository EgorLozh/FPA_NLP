# %%
import os
import wave
import json
from vosk import Model, KaldiRecognizer
from pydub import AudioSegment

# %%
model = Model("../models/vosk-model-small-ru-0.22")
rec = KaldiRecognizer(model, 16000)

# %%
audio = AudioSegment.from_wav("../data/вова.wav")
audio = audio.set_channels(1)  # моно
audio = audio.set_frame_rate(16000)  # частота дискретизации 16000 Hz
audio = audio.set_sample_width(2)  # 16-битный PCM

# %%
audio.export("../data/processed_audio.wav", format="wav")
wf = wave.open("../data/processed_audio.wav", "rb")

# %%
if wf.getnchannels() != 1 or wf.getsampwidth() != 2 or wf.getframerate() != 16000:
    print("Audio file must be WAV format mono PCM.")
    exit(1)

# %%
while True:
    data = wf.readframes(4000)
    if len(data) == 0:
        break
    if rec.AcceptWaveform(data):
        result = rec.Result()
        print(result)
    else:
        print(rec.PartialResult())
# Out:
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : "ночью"
# }
# {
#   "partial" : "ночью улице"
# }
# {
#   "partial" : "ночь улица фонарь"
# }
# {
#   "partial" : "ночь улица фонарь аптека"
# }
# {
#   "partial" : "ночь улица фонарь аптека"
# }
# {
#   "partial" : "ночь улица фонарь аптека"
# }
# {
#   "partial" : "ночь улица фонарь аптека"
# }
# {
#   "partial" : "ночь улица фонарь аптека"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет жилищах"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хочу"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четвертью"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так и"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночки"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночки"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная редко"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек и каналов"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала аптека"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала аптека"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала аптека улице"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала аптека улица фонарь"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала аптека улица фонарь"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала аптека улица фонарь"
# }
# {
#   "partial" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала аптека улица фонарь"
# }

# %%
print(rec.FinalResult())
# Out:
# {
#   "text" : "ночь улица фонарь аптека бессмысленные тусклый свет живи ещё хоть четверть века все будет так исходе нет он раш начнёшь опять сначала повторится все как встарь ночь ледяная рек канала аптека улица фонарь"
# }
